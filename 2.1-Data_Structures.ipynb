# %% [markdown]
# #### <!--NAVIGATION-->
# < [Introduction to python programming language](1-Introduction_to_python_programming_language.ipynb) | [Contents](0-Index.ipynb) | [Logical Operations](2.2-Logical_Operations.ipynb) >

# %% [markdown]
# # 2.1 Conceitos básicos de programação
# ## 2.1.1 Estruturas de dados

# %% [markdown]
#  <a id="top"></a> <br>
# **Conteúdo do *Notebook***
# 1. [Conceitos básicos](#11)
#     1. [Variáveis](#111)
#     1. [Operadores](#112)
# 2. [Estruturas](#2)
#     1. [Estruturas simples](#21)
#     1. [Estruturas](#22)
# 3. [Referências](#3)

# %% [markdown]
# ### <span style="color:red">LEMBRE-SE DE CARREGAR A BIBLIOTECA PARA SUBMETER OS EXERCÍCIOS</span>

# %%
from exercise_client.client import *

# %% [markdown]
# <a id="11"></a> <br>
# ## 1 - Conceitos básicos

# %% [markdown]
# <a id="111"></a> <br>
# ### 1.1 Variáveis
#
# Variáveis podem ser consideradas __recipientes__. Você pode alocar qualquer valor dentro de um recipiente, __sem especificar o tamanho ou tipo__, que geralmente são necessários em outras linguagens de programação. Note que Python é sensivel a letras maiúsculas e minúsculas (*case-sensitive*).
#
# Ao atribuir valores, se coloca a variável a ser criada do lado esquerdo, enquanto o valor a ser atribuido fica do lado direito. A variável e o valor são conectados pelo símbolo (`=`), que significa atribuição <cite data-cite="236589/5T4T73QM"></cite>.

# %% [markdown]
# Nomes de variáveis não podem conter espaços em branco. Se recomenda o uso de "_" em nomes extensos.

# %%
# Python é digitado dinamicamente.
x = 2
y = .5
xy = 'Oi'
z = x+y
print(x,y,xy,z)
# Out:
# 2 0.5 Oi 2.5

# %% [markdown]
# Vamos ver o tipo das variáveis

# %%
type(x)
# Out:
# int

# %%
type(y)
# Out:
# float

# %%
y = 2

# %%
type(y)
# Out:
# int

# %% [markdown]
# ### <span style="color:blue">EXERCÍCIOS:</span>
# #### <span style="color:red">EXECUTE A CÉLULA DO EXERCÍCIO, SELECIONE A REPOSTA E NA SEQUÊNCIA EXECUTE A CÉLULA DE SUBMISSÃO COM
# `check_answer`</span>

# %%
# EXECUTE PARA VISUALIZAR A PERGUNTA
ex = display_question('2.1.1.1')
# Out:
# Crie uma variável de nome 'w', atribuindo o float dez como valor.
# Textarea(value='', layout=Layout(height='100%', width='100%'), placeholder='Escreve o código aqui.')

# %%
# EXECUTE PARA SUBMETER A RESPOSTA DA PERGUNTA ANTERIOR
check_answer(ex)

# %%
# EXECUTE PARA VISUALIZAR A PERGUNTA
ex = display_question('2.1.1.2')
# Out:
# Qual o tipo retornado pela execução do código type('5.0')?
# RadioButtons(options=('Cadeia de caracteres (str)', 'Dicionário (dict)', 'Lista (list)', 'Numérico, inteiro (i…

# %%
# EXECUTE PARA SUBMETER A RESPOSTA DA PERGUNTA ANTERIOR
check_answer(ex)

# %%
# EXECUTE PARA VISUALIZAR A PERGUNTA
ex = display_question('2.1.1.3')
# Out:
# Crie três variáveis númericas, de forma que a 3º, pela soma das 2 primeiras seja igual a 10.
# Textarea(value='', layout=Layout(height='100%', width='100%'), placeholder='x = ?\ny = ?\nz = x+y')

# %%
# EXECUTE PARA SUBMETER A RESPOSTA DA PERGUNTA ANTERIOR
check_answer(ex)

# %% [markdown]
# <a id="112"></a> <br>
# ### 1.2 Operadores

# %% [markdown]
# > <font color="red"><b>Nota</b></font>
#
# >>
# Python suporta diferentes tipos de operadores [*clique para uma lista completa*](https://www.tutorialspoint.com/python/python_basic_operators.htm).
#
# #### Operadores aritméticos
#
# | Símbolo | Operação |
# |----|---|
# | +  | Adição |
# | -  | Subtração |
# | /  | Divisão |
# | %  | Resto |
# | *  | Multiplicação |
# | //  | Divisão de piso (*floor division*) |
# | **  | Potência |
#
#
# ###### [Voltar ao topo](#top)

# %% [markdown]
# <a id="2"></a> <br>
# ## 2 - Estruturas

# %% [markdown]
# <a id="21"></a> <br>
# ### 2.1 - Estruturas simples

# %% [markdown]
# Nesta seção, os tipos de dados considerados [primitivos](https://www.datacamp.com/community/tutorials/data-structures-python#adt) em Python.

# %% [markdown]
# #### Números

# %% [markdown]
# Em Python números inteiros (*integer*) são denominados `int`.

# %%
x = 3
type(x)
# Out:
# int

# %% [markdown]
# As frações (*floating point*) são denominadas `float`.

# %%
y = 3.0
type(y)
# Out:
# float

# %% [markdown]
# Podemos aplicar os operadores aritméticos observadas acima, mas devemos estar atentos a __conversão de tipos__.

# %%
z = 2 * x
type(z)
# Out:
# int

# %%
z = y + x
type(z)
# Out:
# float

# %% [markdown]
# ### <span style="color:blue">EXERCÍCIOS:</span>
# #### <span style="color:red">EXECUTE A CÉLULA DO EXERCÍCIO, SELECIONE A REPOSTA E NA SEQUÊNCIA EXECUTE A CÉLULA DE SUBMISSÃO COM
# `check_answer`</span>

# %%
# EXECUTE PARA VISUALIZAR A PERGUNTA
ex = display_question('2.1.2.1')
# Out:
# Escreva código para calcular a área de um círculo com raio r = 5:
# Textarea(value='', layout=Layout(height='100%', width='100%'), placeholder='Escreve as operações para o cálcul…

# %%
# EXECUTE PARA SUBMETER A RESPOSTA DA PERGUNTA ANTERIOR
check_answer(ex)

# %%
# EXECUTE PARA VISUALIZAR A PERGUNTA
ex = display_question('2.1.2.2')
# Out:
# Crie uma variável x, para que o valor de y, em y = x+5 seja 33
# Textarea(value='', layout=Layout(height='100%', width='100%'), placeholder='x = ?\ny = x+5')

# %%
# EXECUTE PARA SUBMETER A RESPOSTA DA PERGUNTA ANTERIOR
check_answer(ex)

# %%
# EXECUTE PARA VISUALIZAR A PERGUNTA
ex = display_question('2.1.2.3')
# Out:
# Escreva uma operação tal que x = <número> <algum operador> 2 seja 25
# Textarea(value='', layout=Layout(height='100%', width='100%'), placeholder='x = <número> <algum operador> 2 = …

# %%
# EXECUTE PARA SUBMETER A RESPOSTA DA PERGUNTA ANTERIOR
check_answer(ex)

# %% [markdown]
# #### Caracteres

# %% [markdown]
# Em Python, utilizamos o tipo `str` para armazenar letras, palavras e qualquer outro caractere.

# %%
minha_palavra = "queijo"
type(minha_palavra)
# Out:
# str

# %% [markdown]
# Diferentemente de números, `str` são objetos iteráveis, o que significa que podemos ter acesso a cada caractere individual. Como veremos em detalhes adiante, em Python os índices se iniciam com o número 0.

# %%
minha_palavra[0], minha_palavra[2:4]
# Out:
# ('q', 'ei')

# %% [markdown]
# Podemos utilizar o operador `+` para concatenar caracteres diferentes

# %%
minha_palavra + ' Minas'
# Out:
# 'queijo Minas'

# %% [markdown]
# ### <span style="color:blue">EXERCÍCIOS:</span>
# #### <span style="color:red">EXECUTE A CÉLULA DO EXERCÍCIO, SELECIONE A REPOSTA E NA SEQUÊNCIA EXECUTE A CÉLULA DE SUBMISSÃO COM
# `check_answer`</span>

# %%
# EXECUTE PARA VISUALIZAR A PERGUNTA
ex = display_question('2.1.2.4')
# Out:
# Qual letra será selecionada da 'p = "Queijo"', fazendo p[3]:
# RadioButtons(options=('e', 'Q', 'u', 'o', 'i', 'j'), value='e')

# %%
# EXECUTE PARA SUBMETER A RESPOSTA DA PERGUNTA ANTERIOR
check_answer(ex)

# %%
# EXECUTE PARA VISUALIZAR A PERGUNTA
ex = display_question('2.1.2.5')
# Out:
# Escreva o código para imprimir a mensagem 'Olá Mundo' abaixo
# Textarea(value='', layout=Layout(height='100%', width='100%'), placeholder='Escreve o código para impressão aq…

# %%
# EXECUTE PARA SUBMETER A RESPOSTA DA PERGUNTA ANTERIOR
check_answer(ex)

# %%
# EXECUTE PARA VISUALIZAR A PERGUNTA
ex = display_question('2.1.2.6')
# Out:
# Por que não podemos realizar a operação '5'+7
# RadioButtons(options=('A função print não foi utilizada', 'Os objetos na operação são de tipos diferentes', 'O…

# %%
# EXECUTE PARA SUBMETER A RESPOSTA DA PERGUNTA ANTERIOR
check_answer(ex)

# %%
# EXECUTE PARA VISUALIZAR A PERGUNTA
ex = display_question('2.1.2.7')
# Out:
# Crie uma variável com a palavra cachaça e uma segunda variável selecionando as três primeiras letras de cachaça
# Textarea(value='', layout=Layout(height='100%', width='100%'), placeholder="x = 'cachaça'\ny = x[?]")

# %%
# EXECUTE PARA SUBMETER A RESPOSTA DA PERGUNTA ANTERIOR
check_answer(ex)

# %% [markdown]
# #### *Boolean*

# %% [markdown]
# O tipo *boolean* é útil quando necessitamos checar uma condição, por exemplo:

# %%
erro = 1.6
compare_resultado = erro < 0.1
compare_resultado, type(compare_resultado)
# Out:
# (False, bool)

# %% [markdown]
# Existem apenas dois *booleans* válidos: `True` e `False`. Nós também podemos pensar em `1` e `0`, respectivamente.

# %%
erro > 0
# Out:
# True

# %% [markdown]
# Quando usamos valores *boolean* para operações aritméticas, elas automaticamente se tornam `1/0`.

# %%
(erro>0) + 2
# Out:
# 3

# %% [markdown]
# ### <span style="color:blue">EXERCÍCIOS:</span>
# #### <span style="color:red">EXECUTE A CÉLULA DO EXERCÍCIO, SELECIONE A REPOSTA E NA SEQUÊNCIA EXECUTE A CÉLULA DE SUBMISSÃO COM
# `check_answer`</span>

# %%
# EXECUTE PARA VISUALIZAR A PERGUNTA
ex = display_question('2.1.2.8')
# Out:
# Complete a comparação 3 > ? para obter um valor falso:
# Textarea(value='', layout=Layout(height='100%', width='100%'), placeholder='3 > ?')

# %%
# EXECUTE PARA SUBMETER A RESPOSTA DA PERGUNTA ANTERIOR
check_answer(ex)

# %%
# EXECUTE PARA VISUALIZAR A PERGUNTA
ex = display_question('2.1.2.9')
# Out:
# Torne a comparação (3+?) < (30-?) verdadeira:
# Textarea(value='', layout=Layout(height='100%', width='100%'), placeholder='(3+?) < (30-?)')

# %%
# EXECUTE PARA SUBMETER A RESPOSTA DA PERGUNTA ANTERIOR
check_answer(ex)

# %% [markdown]
# #### Conversão de tipos

# %% [markdown]
# Uma vez que variáveis no Python são dinamicamente digitadas, é necessário ser cauteloso com as conversões.
#
# Quando duas variáveis compartilham o mesmo tipo, não há conversão.

# %%
s1 = "sem problemas. "
s2 = "Até mais..."
s1 + s2
# Out:
# 'sem problemas. Até mais...'

# %% [markdown]
# Cuidado quando variáveis são reunidas:

# %%
a = 3 # relembre esse número é um ____?
b = 2.7 # e este?
c = a + b # qual o tipo de `c`?

# %% [markdown]
# Para fazer as coisas funcionarem entre caracteres e números, podemos explicitamente converter números em `str`:

# %%
s1 + 3
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-35-f90ed9df3b77> in <module>
# ----> 1 s1 + 3
#
# TypeError: can only concatenate str (not "int") to str

# %%
s1 + str(3)
# Out:
# 'sem problemas. 3'

# %% [markdown]
# ### <span style="color:blue">EXERCÍCIOS:</span>
# #### <span style="color:red">EXECUTE A CÉLULA DO EXERCÍCIO, SELECIONE A REPOSTA E NA SEQUÊNCIA EXECUTE A CÉLULA DE SUBMISSÃO COM
# `check_answer`</span>

# %%
# EXECUTE PARA VISUALIZAR A PERGUNTA
ex = display_question('2.1.2.10')
# Out:
# Escreva a sentença de forma correta abaixo 'Se tenho 3 laranjas e compro mais 2 terei ' + ?
# Textarea(value='', layout=Layout(height='100%', width='100%'), placeholder="'Se tenho 3 laranjas e compro mais…

# %%
# EXECUTE PARA SUBMETER A RESPOSTA DA PERGUNTA ANTERIOR
check_answer(ex)

# %% [markdown]
# <a id="22"></a> <br>
# ### 2.2 - Estruturas

# %% [markdown]
# Nessa seção, discutiremos algumas estruturas de dados ___nonprimitive___ em Python.
#
# Nós podemos pensar em tipos ___nonprimitive___ como aqueles que podem armazenar dados do tipo ___primitive___.

# %% [markdown]
# #### Lista

# %% [markdown]
# Inicialize uma lista com colchetes. Pode se armazenar qualquer tipo em uma lista simultaneamente.
# - note o uso [___string formatting___](https://pyformat.info/) para representar caracteres
# - `%i` é um espaço reservado para `int`
# - `%s` para `str`

# %%
uma_lista = [1, 2, 3] # vírgulas separam os elementos
print("O tamanho da lista é: %i"%(len(uma_lista)))
print("O 3rd elemento da lista é: %s" %(uma_lista[2])) # Lembre-se em Python contagens começam com 0
print("O ultimo elemento da lista é: %s" %(uma_lista[-1])) # -1 significa o fim da lista
print("A soma da lista é %.2f"%(sum(uma_lista)))
# Out:
# O tamanho da lista é: 3
# O 3rd elemento da lista é: 3
# O ultimo elemento da lista é: 3
# A soma da lista é 6.00

# %% [markdown]
# Podemos criar uma lista com tipos diferentes

# %%
b_lista = [20, True, "bom", "bom"] 
b_lista
# Out:
# [20, True, 'bom', 'bom']

# %% [markdown]
# Atualizando uma lista: __pop__, __remove__, __append__, __extend__

# %%
print(uma_lista)
print("Pop %i fora da lista"%uma_lista.pop(1)) # pop remove o valor do índice informado
print(uma_lista)
# Out:
# [1, 2, 3]
# Pop 2 fora da lista
# [1, 3]

# %%
print("Remove o caractere bom da lista:")
b_lista.remove("bom") # remove o primeiro valor igual ao especificado
print(b_lista)
# Out:
# Remove o caractere bom da lista:
# [20, True, 'bom']

# %%
uma_lista.append(10)
print("Depois de adicionar um novo valor, uma_lista é agora: %s"%(str(uma_lista)))
# Out:
# Depois de adicionar um novo valor, uma_lista é agora: [1, 3, 10]

# %% [markdown]
# Fundir `uma_lista` e `b_lista`:

# %%
uma_lista.extend(b_lista)
print("Fundindo uma_lista and b_lista: %s"%(str(uma_lista)))
# Out:
# Fundindo uma_lista and b_lista: [1, 3, 10, 20, True, 'bom']

# %% [markdown]
# Também podemos usar `+` unir duas listas

# %%
uma_lista + b_lista
# Out:
# [1, 3, 10, 20, True, 'bom', 20, True, 'bom']

# %% [markdown]
# ### <span style="color:blue">EXERCÍCIOS:</span>
# #### <span style="color:red">EXECUTE A CÉLULA DO EXERCÍCIO, SELECIONE A REPOSTA E NA SEQUÊNCIA EXECUTE A CÉLULA DE SUBMISSÃO COM
# `check_answer`</span>

# %%
# EXECUTE PARA VISUALIZAR A PERGUNTA
ex = display_question('2.1.2.11')
# Out:
# Dada uma lista l, de 10 elementos, qual o valor de len(l[1:])?
# RadioButtons(options=('1', '9', '11', '10', '5'), value='1')

# %%
# EXECUTE PARA SUBMETER A RESPOSTA DA PERGUNTA ANTERIOR
check_answer(ex)

# %%
# EXECUTE PARA VISUALIZAR A PERGUNTA
ex = display_question('2.1.2.12')
# Out:
# Dada a lista 'l = [1, 2, 3, 4, 5]' a função l.pop(4) elimina qual número na lista?
# RadioButtons(options=('2', '3', '5', '1', '4'), value='2')

# %%
# EXECUTE PARA SUBMETER A RESPOSTA DA PERGUNTA ANTERIOR
check_answer(ex)

# %%
# EXECUTE PARA VISUALIZAR A PERGUNTA
ex = display_question('2.1.2.13')
# Out:
# Dada a lista 'l=[1,2,3]' qual a diferença entre l.append([4]) e l.extend([4])?
# RadioButtons(options=('extend concatena no incio da lista', 'append substituí os elementos idênticos', 'Os doi…

# %%
# EXECUTE PARA SUBMETER A RESPOSTA DA PERGUNTA ANTERIOR
check_answer(ex)

# %%
# EXECUTE PARA VISUALIZAR A PERGUNTA
ex = display_question('2.1.2.14')
# Out:
# Dada a lista declarada 'l=[1,2,3]' escreva uma linha de código complementar para adicionar dois elementos à lista
# Textarea(value='', layout=Layout(height='100%', width='100%'), placeholder='l = [1,2,3]\n???')

# %%
# EXECUTE PARA SUBMETER A RESPOSTA DA PERGUNTA ANTERIOR
check_answer(ex)

# %% [markdown]
# #### *Tuple* (Um caso especial de lista em que os elementos não podem ser modificados)

# %% [markdown]
# Inicie uma *tuple* com parênteses. A maior diferença entre uma lista e uma *tuple* é que você pode alterar uma lista mas não uma *tuple*.

# %%
uma_tuple = (1, 2, 3, 10)
print(uma_tuple)
print("Primeiro elemento da tuple: %i"%uma_tuple[0])
# Out:
# (1, 2, 3, 10)
# Primeiro elemento da tuple: 1

# %% [markdown]
# Não se pode modificar os valores de uma *tuple*

# %%
uma_tuple[0] = 5
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-45-25ebf24460b0> in <module>
# ----> 1 uma_tuple[0] = 5
#
# TypeError: 'tuple' object does not support item assignment

# %% [markdown]
# Para criar uma *tuple* com um único valor, é preciso adicionar uma ','

# %%
uma_tuple = (1) # cria tipo int
print(type(uma_tuple))
b_tuple = (1,) # cria tipo tuple
print(type(b_tuple))
# Out:
# <class 'int'>
# <class 'tuple'>

# %% [markdown]
# ### <span style="color:blue">EXERCÍCIOS:</span>
# #### <span style="color:red">EXECUTE A CÉLULA DO EXERCÍCIO, SELECIONE A REPOSTA E NA SEQUÊNCIA EXECUTE A CÉLULA DE SUBMISSÃO COM
# `check_answer`</span>

# %%
# EXECUTE PARA VISUALIZAR A PERGUNTA
ex = display_question('2.1.2.15')
# Out:
# O que a operalçao (1,2)+(3,) retorna?
# RadioButtons(options=('Substitui o ultimo elemento da primeira tuple', 'Multiplica os elementos da primeira tu…

# %%
# EXECUTE PARA SUBMETER A RESPOSTA DA PERGUNTA ANTERIOR
check_answer(ex)

# %% [markdown]
# #### Dicionários: pares chave-valor

# %% [markdown]
# Inicie um dicionário com colchetes  `{}`

# %%
d = {} # dicionário vazio
d[1] = "1 value" # adicione um par chave-valor usando um colchete (chave). chave/valor podem ser de qualquer tipo.
print(d)
# Out:
# {1: '1 value'}

# %%
x = {'Eu': 'meuemail@exemplo.com', 'Voce': 'seuemail@exemplo.com'}
x['Eu'] # Recupere o valor utilizando a chave específica
# Out:
# 'meuemail@exemplo.com'

# %% [markdown]
# #### Conjuntos (*sets*)
#
# Um conjunto é uma coleção não ordenada e não indexada. Em Python conjuntos são escritos com colchetes.

# %%
tipos_construcao = {"casa", "apartamento", "prédio"}
print(tipos_construcao)
# Out:
# {'prédio', 'apartamento', 'casa'}

# %% [markdown]
# Conjuntos serão úteis nas próximas seções para comparar listas ou coleções:

# %%
tipos_propriedades = {'caminhão', 'carro','casa'}
tipos_propriedades - tipos_construcao
# Out:
# {'caminhão', 'carro'}

# %%
tipos_propriedades.union(tipos_construcao)
# Out:
# {'apartamento', 'caminhão', 'carro', 'casa', 'prédio'}

# %%
tipos_propriedades.intersection(tipos_construcao)
# Out:
# {'casa'}

# %% [markdown]
# <a id="3"></a> <br>
# ## 3 - Referências
# <div class="cite2c-biblio"></div>
#
# ###### [Voltar ao topo](#top)

# %% [markdown]
# <!--NAVIGATION-->
# < [Introduction to python programming language](1-Introduction_to_python_programming_language.ipynb) | [Contents](0-Index.ipynb) | [Logical Operations](2.2-Logical_Operations.ipynb) >
